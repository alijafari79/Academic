# %% [markdown]
# $\LARGE\text{Project Simulation : Part 2}$

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# $\large Question 1 :$

# %%
# First Define the Transition Matrix :

T_Matrix = {'AAA' : [0.8372, 0.0983, 0.0504, 0.0094, 0.0025, 0.0013, 0.0008, 0.0001],
            'AA'  : [0.0066, 0.9172, 0.0694, 0.0049, 0.0006, 0.0009, 0.0002, 0.0002], 
            'A'   : [0.0007, 0.0225, 0.9176, 0.0518, 0.0049, 0.0020, 0.0001, 0.0004],
            'BBB' : [0.0003, 0.0026, 0.0483, 0.8924, 0.0444, 0.0081, 0.0016, 0.0023],
            'BB'  : [0.0003, 0.0006, 0.0044, 0.0666, 0.8323, 0.0746, 0.0105, 0.0107], 
            'B'   : [0.0002, 0.0009, 0.0031, 0.0046, 0.0572, 0.8362, 0.0384, 0.0594],
            'CCC' : [0.0004, 0.0011, 0.0029, 0.0088, 0.0191, 0.1028, 0.6123, 0.2526],
            'D'   : [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.9972]}

## Sampling Function : in an Efficient Way !!

def Sample(state, rate):

    company = list(T_Matrix.keys())
    sample = []
 
    # Take sample for the next State :
    
    for i in range(rate): 
        
        if state in company :
            state = list(np.random.choice(company,1,1, T_Matrix[state]))[0]
            sample.append(state)
            
        else : sample = 'Invalid State Occurd !'
            
    return sample

# %%
# Check th function :

Sample('AA',200)
# Out:
# ['AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'BBB',
#  'BBB',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AAA',
#  'AAA',
#  'AAA',
#  'AAA',
#  'AAA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'BBB',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
#  'AA',
# ...

# %% [markdown]
# $\large Question 2 :$

# %%
# Transition matrix : 

P = np.array([[0.8372, 0.0983, 0.0504, 0.0094, 0.0025, 0.0013, 0.0008, 0.0001],
              [0.0066, 0.9172, 0.0694, 0.0049, 0.0006, 0.0009, 0.0002, 0.0002],
              [0.0007, 0.0225, 0.9176, 0.0518, 0.0049, 0.0020, 0.0001, 0.0004],
              [0.0003, 0.0026, 0.0483, 0.8924, 0.0444, 0.0081, 0.0016, 0.0023],
              [0.0003, 0.0006, 0.0044, 0.0666, 0.8323, 0.0746, 0.0105, 0.0107],
              [0.0002, 0.0009, 0.0031, 0.0046, 0.0572, 0.8362, 0.0384, 0.0594],
              [0.0004, 0.0011, 0.0029, 0.0088, 0.0191, 0.1028, 0.6123, 0.2526],
              [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.9972]])

ei_value, ei_vector = np.linalg.eig(P)

## resize output number for just 3 Decimal places : ...............
ei_value = [float('%.3f' %element)  for element in ei_value]

for item in ei_vector :
    index = np.where(ei_vector==item)[0][0]
    item = [float('%.3f' %element)  for element in item]
    ei_vector[index] = item

##..............................................................

print('Eigen Values = ', end ='')
print(ei_value)
print('\n')
print('Eigen Vectors = \n')
print(ei_vector)
# Out:
# Eigen Values = [0.596, 1.0, 0.987, 0.932, 0.891, 0.829, 0.845, 0.762]
#
#
# Eigen Vectors =
#
# [[ 0.002 -0.354 -0.544  0.654 -0.713  0.995  0.824  0.   ]
#  [ 0.    -0.354 -0.547  0.617 -0.527 -0.095  0.195 -0.025]
#  [-0.001 -0.354 -0.47   0.094  0.265  0.027 -0.3    0.074]
#  [ 0.002 -0.354 -0.36  -0.214  0.131 -0.019  0.332 -0.266]
#  [-0.007 -0.354 -0.208 -0.295 -0.204 -0.006  0.011  0.797]
#  [ 0.159 -0.354 -0.082 -0.207 -0.271  0.012 -0.267 -0.48 ]
#  [-0.987 -0.354 -0.008 -0.084 -0.107  0.005 -0.105 -0.24 ]
#  [ 0.001 -0.354  0.059  0.003  0.004 -0.001  0.     0.001]]

# %%
#note: the matrix is row stochastic.
#A markov chain transition will correspond to left multiplying by a row vector.

P = np.array([[0.8372, 0.0983, 0.0504, 0.0094, 0.0025, 0.0013, 0.0008, 0.0001],
              [0.0066, 0.9172, 0.0694, 0.0049, 0.0006, 0.0009, 0.0002, 0.0002],
              [0.0007, 0.0225, 0.9176, 0.0518, 0.0049, 0.0020, 0.0001, 0.0004],
              [0.0003, 0.0026, 0.0483, 0.8924, 0.0444, 0.0081, 0.0016, 0.0023],
              [0.0003, 0.0006, 0.0044, 0.0666, 0.8323, 0.0746, 0.0105, 0.0107],
              [0.0002, 0.0009, 0.0031, 0.0046, 0.0572, 0.8362, 0.0384, 0.0594],
              [0.0004, 0.0011, 0.0029, 0.0088, 0.0191, 0.1028, 0.6123, 0.2526],
              [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.9972]])

# Transpose so that Markov transitions correspond to right multiplying by a column vector.  np.linalg.eig finds right eigenvectors.
evals, evecs = np.linalg.eig(P.T)
evec1 = evecs[:,np.isclose(evals, 1)]

#Since np.isclose will return an array, we've indexed with an array
#so we still have our 2nd axis.  Get rid of it, since it's only size 1.
evec1 = evec1[:,0]

stationary = evec1 / evec1.sum()

#eigs finds complex eigenvalues and eigenvectors, so you'll want the real part.
stationary = stationary.real

stationary = [float('%.5f' %element)  for element in stationary]
print('Stationary Distribution : ', end ='')
print(stationary)
# Out:
# Stationary Distribution : [0.00155, 0.0173, 0.04331, 0.03883, 0.02066, 0.01764, 0.00404, 0.85667]

# %% [markdown]
# $\large Question 3 :$

# %%
T = np.arange(1, 21)

state_values = {'AAA': 1, 'AA': 2, 'A': 3, 'BBB': 4, 'BB': 5, 'B': 6, 'CCC': 7, 'D': 8}

# %%
for i in range(5):
    x_AAA = Sample('AAA', 20)
    AAA_values = []
    for states in x_AAA:
        AAA_values.append(state_values[states])
    y_AAA = AAA_values
    plt.plot(T, y_AAA)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State AAA')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_AA = Sample('AA', 20)
    AA_values = []
    for states in x_AA:
        AA_values.append(state_values[states])
    y_AA = AA_values
    plt.plot(T, y_AA)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State AA')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_A = Sample('A', 20)
    A_values = []
    for states in x_A:
        A_values.append(state_values[states])
    y_A = A_values
    plt.plot(T, y_A)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State A')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_BBB = Sample('BBB', 20)
    BBB_values = []
    for states in x_BBB:
        BBB_values.append(state_values[states])
    y_BBB = BBB_values
    plt.plot(T, y_BBB)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State BBB')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_BB = Sample('BB', 20)
    BB_values = []
    for states in x_BB:
        BB_values.append(state_values[states])
    y_BB = BB_values
    plt.plot(T, y_BB)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State BB')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_B = Sample('B', 20)
    B_values = []
    for states in x_B:
        B_values.append(state_values[states])
    y_B = B_values
    plt.plot(T, y_B)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State B')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_CCC = Sample('CCC', 20)
    CCC_values = []
    for states in x_CCC:
        CCC_values.append(state_values[states])
    y_CCC = CCC_values
    plt.plot(T, y_CCC)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State CCC')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_D = Sample('D', 20)
    D_values = []
    for states in x_D:
        D_values.append(state_values[states])
    y_D = D_values
    plt.plot(T, y_D)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State D')
plt.grid(axis ='y')

# %% [markdown]
# $\large Question 4 :$

# %%
T = np.arange(1, 101)

# %%
for i in range(5):
    x_AAA = Sample('AAA', 100)
    AAA_values = []
    for states in x_AAA:
        AAA_values.append(state_values[states])
    y_AAA = AAA_values
    plt.plot(T, y_AAA)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State AAA')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_AA = Sample('AA', 100)
    AA_values = []
    for states in x_AA:
        AA_values.append(state_values[states])
    y_AA = AA_values
    plt.plot(T, y_AA)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State AA')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_A = Sample('A', 100)
    A_values = []
    for states in x_A:
        A_values.append(state_values[states])
    y_A = A_values
    plt.plot(T, y_A)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State A')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_CCC = Sample('CCC', 100)
    CCC_values = []
    for states in x_CCC:
        CCC_values.append(state_values[states])
    y_CCC = CCC_values
    plt.plot(T, y_CCC)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State CCC')
plt.grid(axis ='y')

# %%
for i in range(5):
    x_D = Sample('D', 100)
    D_values = []
    for states in x_D:
        D_values.append(state_values[states])
    y_D = D_values
    plt.plot(T, y_D)
plt.legend(['sim1', 'sim2', 'sim3', 'sim4', 'sim5'])
plt.title('State D')
plt.grid(axis ='y')

# %% [markdown]
# $\large Question 5 :$

# %%
P_pow_2 = np.linalg.matrix_power(P, 2)
P_pow_10 = np.linalg.matrix_power(P, 10)
P_pow_100 = np.linalg.matrix_power(P, 100)
P_pow_1000 = np.linalg.matrix_power(P, 1000)

print(f'P^2 is \n{P_pow_2}')
print(f'P^10 is \n{P_pow_10}')
print(f'P^100 is \n{P_pow_100}')
print(f'P^1000 is \n{P_pow_1000}')
# Out:
# P^2 is
# [[7.0159206e-01 1.7361953e-01 9.5735340e-02 1.9530190e-02 4.9867400e-03
#   2.7096300e-03 1.2755800e-03 5.5093000e-04]
#  [1.1629550e-02 8.4348029e-01 1.2791050e-01 1.2569940e-02 1.6792200e-03
#   1.8305700e-03 3.6696000e-04 5.3297000e-04]
#  [1.3943500e-03 4.1491420e-02 8.4611665e-01 9.4211410e-02 1.1006190e-02
#   4.3244000e-03 3.6946000e-04 1.0861200e-03]
#  [5.8566000e-04 5.8573500e-03 8.7844360e-02 8.0190456e-01 7.7310690e-02
#   1.7579090e-02 3.1919600e-03 5.7263300e-03]
#  [5.4806000e-04 1.4321800e-03 1.1238020e-02 1.1553854e-01 7.0017602e-01
#   1.2610511e-01 1.8147790e-02 2.6814280e-02]
#  [3.8263000e-04 1.7678700e-03 6.1123600e-03 1.2289630e-02 9.6421810e-02
#   7.0752525e-01 5.6272590e-02 1.1922786e-01]
#  [6.4328000e-04 1.9644000e-03 5.4367500e-03 1.5246710e-02 3.4004910e-02
#   1.5056081e-01 3.7925109e-01 4.1289205e-01]
#  [1.8564000e-04 4.0211000e-04 6.1877000e-04 8.1552000e-04 9.8204000e-04
#   1.2134500e-03 1.1557300e-03 9.9462674e-01]]
# P^10 is
# ...

# %% [markdown]
# $\text{It's obvious that Bankruptcy is an absorbing state that if a company go on that state, will get stuck in there .}$

# %% [markdown]
# $\large Question 7 :$

# %%
rate = 10000
states = ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'D']
S = Sample('AAA', rate)
n = {'AAA': 0 , 'AA' : 0 , 'A' : 0, 'BBB' : 0, 'BB':0, 'B':0, 'CCC': 0, 'D' :0}

## Count number of each state accured :
for state in states : 
    n[state] = S.count(state)

for state in states:
    print(f'state {state} ratio is {n[state]/rate} \n')
# Out:
# state AAA ratio is 0.0044
#
# state AA ratio is 0.0136
#
# state A ratio is 0.0467
#
# state BBB ratio is 0.0481
#
# state BB ratio is 0.0242
#
# state B ratio is 0.0233
#
# state CCC ratio is 0.0048
#
# state D ratio is 0.8349
